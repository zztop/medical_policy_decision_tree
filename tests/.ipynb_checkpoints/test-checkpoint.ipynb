# %%
from google.adk.runners import InMemoryRunner
from google.genai.types import Part, UserContent
import textwrap
from pydantic import TypeAdapter


from medical_policy_decision_tree_agent.policy_orchestrator_agent import policy_orchestrator_agent

from medical_policy_decision_tree_agent.prior_auth_decision_trees import PriorAuthDecisionTrees

import dotenv

dotenv.load_dotenv()

agent_response=""
final_response =None

user_input = textwrap.dedent(
        """
        https://www.bluecrossma.org/medical-policies/sites/g/files/csphws2091/files/acquiadam-assets/121%20Closure%20Devices%20for%20Patent%20Foramen%20Ovale%20and%20Atrial%20Septal%20Defects%20prn.pdf
    """
    ).strip()
content = UserContent(parts=[Part(text=user_input)])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 import textwrap
#       4 from pydantic import TypeAdapter
# ----> 7 from medical_policy_decision_tree_agent.policy_orchestrator_agent import policy_orchestrator_agent
#       9 from medical_policy_decision_tree_agent.prior_auth_decision_trees import PriorAuthDecisionTrees
#      11 import dotenv
#
# File /data-drive/development/Development/llm/medical_policy_decision_tree/medical_policy_decision_tree_agent/__init__.py:1
# ----> 1 from . import policy_orchestrator_agent, tools, prior_auth_decision_trees
#       3 __all__ = ["policy_orchestrator_agent", "tools", "prior_auth_decision_trees"]
#
# File /data-drive/development/Development/llm/medical_policy_decision_tree/medical_policy_decision_tree_agent/policy_orchestrator_agent.py:3
#       1 from google.adk.agents import LlmAgent
# ----> 3 from medical_policy_decision_agent import medical_policy_decision_agent
#       4 from google.adk.tools.mcp_tool import MCPToolset, StreamableHTTPConnectionParams
#       7 medical_policy_storage_mcp_tool = MCPToolset(
#       8     connection_params=StreamableHTTPConnectionParams(url="http://localhost:8080/mcp")
#       9 )
#
# ModuleNotFoundError: No module named 'medical_policy_decision_agent'

# %%
runner = InMemoryRunner(agent=medical_policy_decision_tree_agent.policy_orchestrator_agent)
session = await runner.session_service.create_session(
    app_name=runner.app_name, user_id="test_user"
)
async for event in runner.run_async(
    user_id=session.user_id,
    session_id=session.id,
    new_message=content,
):
        print(event)
        if event and event.is_final_response():
            if event.content and  event.content.parts and event.content.parts[0].text:
                agent_response = event.content.parts[0].text
                print(f"Response is : {agent_response}")
        if agent_response:
            final_response = TypeAdapter(PriorAuthDecisionTrees).validate_json(agent_response)
            print(final_response)
            print(type(final_response))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3 import textwrap
#       4 from pydantic import TypeAdapter
# ----> 7 from medical_policy_decision_tree_agent.medical_policy_decision_agent import medical_policy_decision_agent
#      10 from medical_policy_decision_tree_agent.policy_orchestrator_agent import policy_orchestrator_agent
#      12 from medical_policy_decision_tree_agent.prior_auth_decision_trees import PriorAuthDecisionTrees
#
# ModuleNotFoundError: No module named 'medical_policy_decision_tree_agent'
